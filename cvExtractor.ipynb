# %%
pip install pdfminer
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#       --------------------------------------- 0.1/4.2 MB 299.4 kB/s eta 0:00:14
#       --------------------------------------- 0.1/4.2 MB 328.8 kB/s eta 0:00:13
#       --------------------------------------- 0.1/4.2 MB 350.1 kB/s eta 0:00:12
#       --------------------------------------- 0.1/4.2 MB 350.1 kB/s eta 0:00:12
#       --------------------------------------- 0.1/4.2 MB 350.1 kB/s eta 0:00:12
#      - -------------------------------------- 0.1/4.2 MB 262.6 kB/s eta 0:00:16
#      - -------------------------------------- 0.1/4.2 MB 257.8 kB/s eta 0:00:16
# ...

# %%
pip install groq
# Out:
# ...
#    ---------------------------------------- 0.0/103.5 kB ? eta -:--:--
#    ----------- ---------------------------- 30.7/103.5 kB 1.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 92.2/103.5 kB 1.1 MB/s eta 0:00:01
#    -------------------------------------- 103.5/103.5 kB 847.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#    ---------------------------- ----------- 61.4/86.8 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 86.8/86.8 kB 981.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/75.6 kB ? eta -:--:--
#    --------------------- ------------------ 41.0/75.6 kB 960.0 kB/s eta 0:00:01
#    ---------------------------------------- 75.6/75.6 kB 1.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/77.9 kB ? eta -:--:--
#    ------------------------------- -------- 61.4/77.9 kB 1.1 MB/s eta 0:00:01
# ...

# %%
from pdfminer.pdfparser import PDFParser

# %%
from pdfminer.pdfparser import PDFParser
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from io import StringIO

with open('C:\\Users\\User\\Downloads\\AdemSaidi2.pdf', 'rb') as fp:
    parser = PDFParser(fp)
    document = PDFDocument(parser)
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, laparams=laparams)    
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    for page in PDFPage.create_pages(document):
        interpreter.process_page(page)
    text = retstr.getvalue()
    retstr.close()
    device.close()  
    print(text)
# Out:
# ADEM SAIDI
#
# +21653531995 | adem.saidi@insat.ucar.tn | Tunisia | linkedin.com/in/adem-saidi-040399280/ | github.com/saidiadem
#
# SUMMARY
#
# I am a software engineering student in my second year with a passion for new technologies . I adapt quickly and like problem
#
# solving
#
# EDUCATION
#
# INSAT
#
# Bachelor's, Software Engineering
#
# September 2022 - September 2027
#
# •   Member of the IT Department of Junior Entreprise INSAT where i contributed to many projects.
#
# CERTIFICATIONS
#
# 4th place in the Cybersphere Capture the flag 2024 where i mostly solved reverse engineering and web exploitation tasks.
#
# PROFESSIONAL EXPERIENCE
#
# Billcom
#
# Web developer
#
# Sousse, Tunisia
# August 2023 - August 2023
# •   Made a web application that manages clients and assigns phone numbers for them . Basically a dashboard for an employee
#
# at a phone company .
#
# •   Technologies : HTML-CSS-Springboot-MySQL
#
# PROJECTS & OUTSIDE EXPERIENCE
#
# SpendPennyWise
#
# ...

# %%
from groq import Groq

client = Groq(
    api_key="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"
)
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "extract from this string the relevant information about this cv and return it in this object format "+text,
        }
    ],
    model="llama3-8b-8192",
)

print(chat_completion.choices[0].message.content)
# Out:
# Here is the relevant information about Adem Saidi's CV in the object format:
#
# ```
# {
#   "name": "Adem Saidi",
#   "contact": {
#     "phone": "+21653531995",
#     "email": "adem.saidi@insat.ucar.tn",
#     "linkedIn": "linkedin.com/in/adem-saidi-040399280/",
#     "github": "github.com/saidiadem"
#   },
#   "summary": "Software engineering student with a passion for new technologies, adapting quickly and enjoying problem-solving.",
#   "education": {
#     "university": "INSAT",
#     "degree": "Bachelor's in Software Engineering",
#     "dates": "September 2022 - September 2027",
#     "activities": "Member of the IT Department of Junior Entreprise INSAT, contributing to many projects."
#   },
#   "certifications": {
#     "title": "4th place in the Cybersphere Capture the flag 2024",
#     "description": "Reverse engineering and web exploitation tasks"
#   },
#   "experience": [
#     {
#       "company": "Billcom",
#       "position": "Web Developer",
# ...
